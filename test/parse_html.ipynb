# %%
html_path = './html/CI00005593.html'

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(open(html_path, 'rb'), 'html.parser', from_encoding='urf-8')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <base href="/mu/"/>
# <title>上海博物馆</title>
# <link href="site/img/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="site/lib/baguettebox/baguetteBox.min.css" rel="stylesheet"/>
# <link href="site/lib/sharejs/css/share.min.css" rel="stylesheet"/>
# <link href="site/lib/luxbar/luxbar.min.css" rel="stylesheet"/>
# <link href="site/lib/fontawesome/css/all.min.css" rel="stylesheet"/>
# <link href="site/lib/video.js/video-js.min.css" rel="stylesheet"/>
# <link href="site/lib/video.js/themes/fantasy/index.css" rel="stylesheet"/>
# <link href="site/lib/tooltipster/css/tooltipster.bundle.min.css" rel="stylesheet"/>
# <link href="site/lib/tooltipster/css/plugins/tooltipster/sideTip/themes/tooltipster-sideTip-borderless.min.css" rel="stylesheet"/>
# ...

# %%
a = soup.find('ul', class_='shmu-breadcrumb-nav').get_text()

# %%
a
# Out:
# '\n\n首页\n\n\n典藏\n\n\n典藏精选\n\n\n\n\t\t\t\t\t\t\t\t书画\n\t\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t\t书法\n\t\t\t\t\t\t\t\n\n'

# %%
a.split()
# Out:
# ['首页', '典藏', '典藏精选', '书画', '书法']
